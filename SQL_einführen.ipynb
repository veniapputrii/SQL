# %% [markdown]
# <a href="https://colab.research.google.com/github/veniapputrii/SQL/blob/Starter/SQL_einf%C3%BChren.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#12. Feb 2026
#lerne über Datenbank in SQL

import sqlite3
import pandas as pd

#Ich öffne eine Verbindung zu einer neuen Datenbank

conn = sqlite3.connect('firma.db')

#Erstelle Test-Daten (Mitararbeiter)
daten = {
    'Name' : ['Anna', 'Nia', 'Clara', 'David'],
    'Abteilung' : ['IT', 'Sales', 'IT', 'HR'],
    'Gehalt' : [50000, 32000, 48000, 2900]
}

df_tmp = pd.DataFrame(daten)
#schreibe die Daten in die SQL-Datenbank
#die Tabelle in der Datenbank soll 'Mitarbeiter' heißen
df_temp.to_sql('Mitarbeiter', conn, index=False, if_exists='replace')

print( 'Datenbank "firma.db" erstellt und Tabelle
"Mitarbeiter" gefüllt! ')
# Out:
#   File "/tmp/ipython-input-2594855864.py", line 23
#     print('Datenbank "firma.db" erstellt und Tabelle
#           ^
# SyntaxError: unterminated string literal (detected at line 23)
