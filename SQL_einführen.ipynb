# %% [markdown]
# <a href="https://colab.research.google.com/github/veniapputrii/SQL/blob/main/SQL_einf%C3%BChren.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#12. Feb 2026
#lerne über Datenbank in SQL

import sqlite3
import pandas as pd

#Ich öffne eine Verbindung zu einer neuen Datenbank

conn = sqlite3.connect('firma.db')

#Erstelle Test-Daten (Mitararbeiter)
daten = {
    'Name' : ['Anna', 'Nia', 'Clara', 'David'],
    'Abteilung' : ['IT', 'Sales', 'IT', 'HR'],
    'Gehalt' : [50000, 32000, 48000, 2900]
}
df_tmp = pd.DataFrame(daten)
#schreibe die Daten in die SQL-Datenbank
#die Tabelle in der Datenbank soll 'Mitarbeiter' heißen
df_tmp.to_sql('Mitarbeiter', conn, index=False, if_exists='replace')

print("Datenbank 'firma.db' erstellt und Tabelle 'Mitarbeiter' gefüllt !")
# Out:
# Datenbank 'firma.db' erstellt und Tabelle 'Mitarbeiter' gefüllt !

# %%
#13. Feb. 2026
#Wir haben eine Tabelle für einen Online-Shop namens Kunden.
import sqlite3
import pandas as pd

#Verbindung zur Datenbank herstellen (produce)
conn = sqlite3.connect(':memory:')

#Tabelle erstellen
conn.execute('''
CREATE TABLE Kunden(
  ID INTEGER PRIMARY KEY,
  Name TEXT,
  Stadt TEXT,
  "Alter" INTEGER
)
''')

#Daten einfügen
kunden_daten= [
    (1, 'Max', 'Berlin', 30),
    (2, 'Nana', 'Hamburg', 28),
    (3, 'Lukas', 'Aachen', 32),
    (4, 'Julia', 'München', 29)
]
conn.executemany('INSERT INTO Kunden VALUES(?,?,?,?)', kunden_daten)

#Funktion zum Anzeigen der Ergebnisse
def sql(query):
  return pd.read_sql_query(query, conn)

print("Datenbank bereit!")
# Out:
# Datenbank bereit!

# %%
sql("SELECT * FROM Kunden")
# Out:
#    ID   Name    Stadt  Alter
# 0   1    Max   Berlin     30
# 1   2   Nana  Hamburg     28
# 2   3  Lukas   Aachen     32
# 3   4  Julia  München     29

# %%
sql("SELECT Stadt FROM Kunden")
# Out:
# Empty DataFrame
# Columns: [Stadt]
# Index: []

# %%
sql("SELECT Stadt FROM Kunden")
# Out:
# Empty DataFrame
# Columns: [Stadt]
# Index: []

# %%
conn.execute("INSERT INTO Kunden (ID, Name, Stadt, \"Alter\") VALUES (6, 'Markus', 'Berlin', 35)")
print("Markus wurde hinzugefügt!")
# Out:
# Markus wurde hinzugefügt!

# %%
sql("SELECT Stadt FROM Kunden")
# Out:
#     Stadt
# 0  Berlin
# 1  Berlin
